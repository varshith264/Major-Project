# %%
from Predictions import predicted
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from hmmlearn.hmm import GaussianHMM, GMMHMM
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.title("Line graph")
plt.ylabel("Price(USD")
plt.plot(predicted, color ="green")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from Results import*

# %%
from matplotlib import pyplot as plt
import numpy as np
 
 
# Creating dataset
a = np.array(lstmRmseValues)
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = [18.5, 19,19.5, 20,20.5,21,21.5, 22,22.5,23,23.5,24,24.5,25,25.5,26,26.5,27,27.5,28,28.5,29])
plt.xlabel("LSTM_RMSE")
plt.ylabel("counts")
 
# Show plot
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
 
 
# Creating dataset
a = np.array(gruRmseValues)
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = [18.5, 19,19.5, 20,20.5,21,21.5, 22,22.5,23,23.5,24,24.5,25,25.5,26,26.5,27,27.5,28])
plt.xlabel("GRU_RMSE")
plt.ylabel("counts")
 
# Show plot
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
 
 
# Creating dataset
a = np.array(gruMapeValues)
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
bins=np.linspace(0.0020,0.0045,15)
ax.hist(a, bins)
plt.xlabel("GRU_MAPE")
plt.ylabel("counts")
 
# Show plot
plt.show()

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16);

# %%
data = pd.read_csv('/content/drive/MyDrive/S7 Project/BTC.csv')
data = data[4278:47892]

# %%
arr=[1,2,3,4,5,6,7]
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)
arr=test_data.Close.tolist()

# %%
line_plot(arr,predicted,"Actual","Predicted")
